# %% [markdown]
# ## To split data into correct hierarchy, run this notebook from top to bottom

# %%
import os, sys
import glob
import shutil
import json
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import warnings
from IPython.display import display
FOLD='5'

# %%
def validate_split(df):
    """
    Checks-
    1. Each row should be either unknown (mos/non-mos), genus_spp or a known species.
    2. SPECIES_TO_PATH contains all valid folders with images. Check that the name in dataframe 
        exists in the actual directory.
    3. Warn if number of images in the directory does not match what csv says.
    """
    for i in range(len(df)):
        unk = df.loc[i, 'unknown']
        gknown = df.loc[i, 'genus']
        sknown = df.loc[i, 'species']
        assert pd.isnull(unk) + pd.isnull(gknown) + pd.isnull(sknown) == 2, "Error at Row index {}".format(i)
        assert df.loc[i, 'folder'] in SPECIES_TO_PATH, "Error at Row index {}, '{}' not found.".format(i, df.loc[i, 'folder'])
        nfiles = len(glob.glob(SPECIES_TO_PATH[df.loc[i, 'folder']] + '*m.*'))
        if nfiles != df.loc[i, 'm']:
            print("Index {}, Files found in {}: {}, Files according to split: {}".format(
                i, SPECIES_TO_PATH[df.loc[i, 'folder']], nfiles, df.loc[i, 'm']))
    print("K.")
    
def class_rename_util(cname):
    """
    'aedes aegypti' -> 'aedes aedes_aegypti'
    """
    if pd.isnull(cname): return cname
    assert len(cname.split(' ')) > 1
    species = cname.split(' ')[-1]
    return cname.replace(species, cname.replace(' ', '_'))

# %%
split_df = pd.read_excel(f'./unk training - 1.29.2020 - reduced.xlsx', sheet_name='fold{}'.format(FOLD))
split_df = split_df[split_df['ignore'] != 'YES'].reset_index(drop=True)
split_df['genus'] = split_df['genus'].apply(class_rename_util)
split_df['species'] = split_df['species'].apply(class_rename_util)
with pd.option_context("display.max_rows", 1000):
    display(split_df)
# Out:
#    ignore   unknown                      genus  \
# 0   NaN    NaN       NaN
# 1   NaN    NaN       NaN
# 2   NaN    NaN       aedes aedes_spp
# 3   NaN    NaN       aedes aedes_spp
# 4   NaN    NaN       aedes aedes_spp
# 5   NaN    NaN       aedes aedes_spp
# 6   NaN    NaN       aedes aedes_spp
# 7   NaN    NaN       NaN
# 8   NaN    NaN       aedes aedes_spp
# 9   NaN    NaN       aedes aedes_spp
# 10  NaN    NaN       aedes aedes_spp
# 11  NaN    NaN       aedes aedes_spp
# 12  NaN    NaN       aedes aedes_spp
# 13  NaN    NaN       aedes aedes_spp
# 14  NaN    NaN       aedes aedes_spp
# 15  NaN    NaN       aedes aedes_spp
# 16  NaN    NaN       aedes aedes_spp
# 17  NaN    NaN       NaN
# 18  NaN    NaN       aedes aedes_spp
# 19  NaN    NaN       aedes aedes_spp
# 20  NaN    NaN       NaN
# 21  NaN    NaN       aedes aedes_spp
# 22  NaN    NaN       aedes aedes_spp
# 23  NaN    NaN       aedes aedes_spp
# 24  NaN    NaN       NaN
# 25  NaN    NaN       anopheles anopheles_spp
# 26  NaN    NaN       NaN
# 27  NaN    NaN       anopheles anopheles_spp
# 28  NaN    NaN       anopheles anopheles_spp
# 29  NaN    NaN       anopheles anopheles_spp
# 30  NaN    NaN       anopheles anopheles_spp
# 31  NaN    NaN       anopheles anopheles_spp
# 32  NaN    NaN       anopheles anopheles_spp
# 33  NaN    NaN       NaN
# 34  NaN    NaN       NaN
# 35  NaN    NaN       NaN
# 36  NaN    NaN       NaN
# 37  NaN    NaN       NaN
# 38  NaN    NaN       NaN
# 39  NaN    NaN       NaN
# 40  NaN    NaN       anopheles anopheles_spp
# 41  NaN    NaN       anopheles anopheles_spp
# 42  NaN    NaN       anopheles anopheles_spp
# 43  NaN    NaN       anopheles anopheles_spp
# 44  NaN    NaN       anopheles anopheles_spp
# 45  NaN    NaN       NaN
# 46  NaN    NaN       NaN
# 47  NaN    NaN       anopheles anopheles_spp
# 48  NaN    NaN       anopheles anopheles_spp
# 49  NaN    NaN       anopheles anopheles_spp
# 50  NaN    NaN       anopheles anopheles_spp
# 51  NaN    mosquito  NaN
# 52  NaN    NaN       culex culex_spp
# 53  NaN    NaN       culex culex_spp
# 54  NaN    NaN       culex culex_spp
# 55  NaN    NaN       culex culex_spp
# 56  NaN    NaN       culex culex_spp
# 57  NaN    NaN       NaN
# 58  NaN    NaN       culex culex_spp
# 59  NaN    NaN       NaN
# 60  NaN    NaN       culex culex_spp
# 61  NaN    NaN       culex culex_spp
# 62  NaN    mosquito  NaN
# 63  NaN    mosquito  NaN
# 64  NaN    mosquito  NaN
# 65  NaN    mosquito  NaN
# 66  NaN    mosquito  NaN
# 67  NaN    mosquito  NaN
# 68  NaN    mosquito  NaN
# 69  NaN    NaN       psorophora psorophora_spp
# 70  NaN    NaN       NaN
# 71  NaN    NaN       NaN
# 72  NaN    NaN       psorophora psorophora_spp
# 73  NaN    NaN       psorophora psorophora_spp
# 74  NaN    NaN       psorophora psorophora_spp
# 75  NaN    NaN       psorophora psorophora_spp
# 76  NaN    NaN       psorophora psorophora_spp
# 77  NaN    NaN       psorophora psorophora_spp
# 78  NaN    mosquito  NaN
#
#                                 species                           folder  \
# 0   aedes aedes_aegypti                  aedes aegypti
# 1   aedes aedes_albopictus               aedes albopictus
# 2   NaN                                  aedes atlanticus
# 3   NaN                                  aedes canadensis
# 4   NaN                                  aedes cantator
# 5   NaN                                  aedes cinereus
# 6   NaN                                  aedes condolescens
# 7   aedes aedes_dorsalis                 aedes dorsalis
# 8   NaN                                  aedes fairfax-1
# 9   NaN                                  aedes flavescens
# 10  NaN                                  aedes hendersoni
# 11  NaN                                  aedes infirmatus
# 12  NaN                                  aedes japonicus
# 13  NaN                                  aedes mediovittatus
# 14  NaN                                  aedes melanimon
# 15  NaN                                  aedes nigromaculis
# 16  NaN                                  aedes sierrensis
# 17  aedes aedes_sollicitans              aedes sollicitans
# 18  NaN                                  aedes spilotus
# 19  NaN                                  aedes sticticus
# 20  aedes aedes_taeniorhynchus           aedes taeniorhynchus
# 21  NaN                                  aedes tortilis
# 22  NaN                                  aedes triseriatus_sl sl
# 23  NaN                                  aedes trivittatus
# 24  aedes aedes_vexans                   aedes vexans
# 25  NaN                                  anopheles cf-coustani
# 26  anopheles anopheles_coustani         anopheles coustani
# 27  NaN                                  anopheles crucians_sl a
# 28  NaN                                  anopheles crucians_sl b
# 29  NaN                                  anopheles crucians_sl c
# 30  NaN                                  anopheles crucians_sl sl
# 31  NaN                                  anopheles crucians_sl d
# 32  NaN                                  anopheles crucians_sl e
# 33  anopheles anopheles_freeborni        anopheles freeborni
# 34  anopheles anopheles_funestus         anopheles funestus_sl sl
# 35  anopheles anopheles_funestus         anopheles funestus_sl ss
# 36  anopheles anopheles_gambiae          anopheles gambiae_sl arabiensis
# 37  anopheles anopheles_gambiae          anopheles gambiae_sl coluzzii
# 38  anopheles anopheles_gambiae          anopheles gambiae_sl sl
# 39  anopheles anopheles_gambiae          anopheles gambiae_sl ss
# 40  NaN                                  anopheles maculipalpis
# 41  NaN                                  anopheles maculipennis
# 42  NaN                                  anopheles pharoensis
# 43  NaN                                  anopheles pretoriensis
# 44  NaN                                  anopheles pseudopunctipennis
# 45  anopheles anopheles_punctipennis     anopheles punctipennis
# 46  anopheles anopheles_quadrimaculatus  anopheles quadrimaculatus
# 47  NaN                                  anopheles rufipes
# 48  NaN                                  anopheles squamosus
# 49  NaN                                  anopheles tenebrosus
# 50  NaN                                  anopheles ziemanni
# 51  NaN                                  coquillettidia perturbans
# 52  NaN                                  culex antillummagnorum
# 53  NaN                                  culex bahamensis
# 54  NaN                                  culex coronator
# 55  NaN                                  culex erraticus
# 56  NaN                                  culex nigripalpus
# 57  culex culex_pipiens_sl               culex pipiens_sl
# 58  NaN                                  culex restuans
# 59  culex culex_salinarius               culex salinarius
# 60  NaN                                  culex tarsalis
# 61  NaN                                  culex territans
# 62  NaN                                  culiseta incidens
# 63  NaN                                  culiseta inornata
# 64  NaN                                  culiseta melanura
# 65  NaN                                  deinocerites cancer
# 66  NaN                                  deinocerites cuba-1
# 67  NaN                                  mansonia titillans
# 68  NaN                                  orthopodomyia signifera
# 69  NaN                                  psorophora ciliata
# 70  psorophora psorophora_columbiae      psorophora columbiae
# 71  psorophora psorophora_cyanescens     psorophora cyanescens
# 72  NaN                                  psorophora discolor
# 73  NaN                                  psorophora ferox
# 74  NaN                                  psorophora horrida
# 75  NaN                                  psorophora howardii
# 76  NaN                                  psorophora pygmaea
# 77  NaN                                  psorophora signipennis
# 78  NaN                                  uranotaenia sapphirina
#
#        m  specimens    fold
# 0   896   188        tr/v/t
# 1   725   155        tr/v/t
# 2   80    16         tr/v/t
# 3   46    9          tr/v/t
# 4   8     2          test
# 5   0     0          test
# 6   10    2          test
# 7   288   55         tr/v/t
# 8   6     1          test
# 9   72    16         tr/v/t
# 10  16    4          test
# 11  106   21         test
# 12  1103  252        test
# 13  13    3          test
# 14  20    5          test
# 15  42    7          tr/v/t
# 16  8     2          test
# 17  414   91         tr/v/t
# 18  4     1          test
# 19  4     1          test
# 20  184   35         tr/v/t
# 21  21    4          tr/v/t
# 22  87    18         tr/v/t
# 23  143   29         test
# 24  295   60         tr/v/t
# 25  21    2          tr/v/t
# 26  148   26         tr/v/t
# 27  19    4          test
# 28  39    8          test
# 29  14    3          test
# 30  205   41         test
# 31  5     1          test
# 32  5     1          test
# 33  574   120        tr/v/t
# 34  28    7          tr/v/t
# 35  972   173        tr/v/t
# 36  753   139        tr/v/t
# 37  96    16         tr/v/t
# 38  222   43         tr/v/t
# 39  110   21         tr/v/t
# 40  30    6          tr/v/t
# 41  0     0          test
# 42  6     1          test
# 43  12    2          test
# 44  53    10         tr/v/t
# 45  223   46         tr/v/t
# 46  195   37         tr/v/t
# 47  12    2          test
# 48  13    3          test
# 49  6     1          test
# 50  35    7          tr/v/t
# 51  127   27         tr/v/t
# 52  13    3          test
# 53  4     1          test
# 54  61    12         tr/v/t
# 55  346   72         test
# 56  74    16         tr/v/t
# 57  1496  313        tr/v/t
# 58  80    18         tr/v/t
# 59  172   34         tr/v/t
# 60  14    3          test
# 61  13    2          test
# 62  53    12         tr/v/t
# 63  46    10         tr/v/t
# 64  5     1          test
# 65  39    8          tr/v/t
# 66  72    15         tr/v/t
# 67  93    19         tr/v/t
# 68  18    3          test
# 69  173   30         tr/v/t
# 70  403   81         tr/v/t
# 71  390   78         tr/v/t
# 72  10    2          test
# 73  231   44         test
# 74  0     0          test
# 75  17    3          test
# 76  149   30         tr/v/t
# 77  23    5          tr/v/t
# 78  10    2          test

# %%
"""
SPECIES_TO_PATH maps folder names to paths on the hard drive
"""
SPECIES_TO_PATH = {}
genus_folders = glob.glob(f'/opt/ImageBase/AWS_sync/cropped/*/')
for genus_folder in genus_folders:
    species_folders = glob.glob(genus_folder + '*/')
    for species_folder in species_folders:
        gen_sp = ' '.join(species_folder.split('/')[-3:-1])
        SPECIES_TO_PATH[gen_sp] = species_folder
        
        sub_species_folders = glob.glob(species_folder + '*/')
        for sub_species_folder in sub_species_folders:
            gen_sp_subsp = ' '.join(sub_species_folder.split('/')[-4:-1])
            SPECIES_TO_PATH[gen_sp_subsp] = sub_species_folder

SPECIES_TO_PATH['non_mosquito'] = '/opt/ImageBase/AWS_sync/cropped/non_mosquito/'

# %%
SPECIES_TO_PATH
# Out:
# {'psorophora pygmaea': '/opt/ImageBase/AWS_sync/cropped/psorophora/pygmaea/',
#  'psorophora howardii': '/opt/ImageBase/AWS_sync/cropped/psorophora/howardii/',
#  'psorophora discolor': '/opt/ImageBase/AWS_sync/cropped/psorophora/discolor/',
#  'psorophora cyanescens': '/opt/ImageBase/AWS_sync/cropped/psorophora/cyanescens/',
#  'psorophora ciliata': '/opt/ImageBase/AWS_sync/cropped/psorophora/ciliata/',
#  'psorophora spp': '/opt/ImageBase/AWS_sync/cropped/psorophora/spp/',
#  'psorophora columbiae': '/opt/ImageBase/AWS_sync/cropped/psorophora/columbiae/',
#  'psorophora ferox': '/opt/ImageBase/AWS_sync/cropped/psorophora/ferox/',
#  'psorophora horrida': '/opt/ImageBase/AWS_sync/cropped/psorophora/horrida/',
#  'psorophora signipennis': '/opt/ImageBase/AWS_sync/cropped/psorophora/signipennis/',
#  'anopheles pharoensis': '/opt/ImageBase/AWS_sync/cropped/anopheles/pharoensis/',
#  'anopheles cf-coustani': '/opt/ImageBase/AWS_sync/cropped/anopheles/cf-coustani/',
#  'anopheles maculipennis': '/opt/ImageBase/AWS_sync/cropped/anopheles/maculipennis/',
#  'anopheles gambiae_sl': '/opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/',
#  'anopheles gambiae_sl arabiensis': '/opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/arabiensis/',
#  'anopheles gambiae_sl coluzzii': '/opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/coluzzii/',
#  'anopheles gambiae_sl ss': '/opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/ss/',
#  'anopheles gambiae_sl sl': '/opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/sl/',
#  'anopheles coustani': '/opt/ImageBase/AWS_sync/cropped/anopheles/coustani/',
#  'anopheles rufipes': '/opt/ImageBase/AWS_sync/cropped/anopheles/rufipes/',
#  'anopheles tenebrosus': '/opt/ImageBase/AWS_sync/cropped/anopheles/tenebrosus/',
#  'anopheles bradleyi': '/opt/ImageBase/AWS_sync/cropped/anopheles/bradleyi/',
#  'anopheles crucians_sl': '/opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/',
#  'anopheles crucians_sl b': '/opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/b/',
#  'anopheles crucians_sl a': '/opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/a/',
#  'anopheles crucians_sl sl': '/opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/sl/',
#  'anopheles crucians_sl e': '/opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/e/',
#  'anopheles crucians_sl c': '/opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/c/',
#  'anopheles crucians_sl d': '/opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/d/',
#  'anopheles pseudopunctipennis': '/opt/ImageBase/AWS_sync/cropped/anopheles/pseudopunctipennis/',
#  'anopheles squamosus': '/opt/ImageBase/AWS_sync/cropped/anopheles/squamosus/',
#  'anopheles punctipennis': '/opt/ImageBase/AWS_sync/cropped/anopheles/punctipennis/',
#  'anopheles funestus_sl': '/opt/ImageBase/AWS_sync/cropped/anopheles/funestus_sl/',
#  'anopheles funestus_sl ss': '/opt/ImageBase/AWS_sync/cropped/anopheles/funestus_sl/ss/',
#  'anopheles funestus_sl sl': '/opt/ImageBase/AWS_sync/cropped/anopheles/funestus_sl/sl/',
#  'anopheles spp': '/opt/ImageBase/AWS_sync/cropped/anopheles/spp/',
#  'anopheles maculipalpis': '/opt/ImageBase/AWS_sync/cropped/anopheles/maculipalpis/',
#  'anopheles quadrimaculatus': '/opt/ImageBase/AWS_sync/cropped/anopheles/quadrimaculatus/',
#  'anopheles ziemanni': '/opt/ImageBase/AWS_sync/cropped/anopheles/ziemanni/',
#  'anopheles pretoriensis': '/opt/ImageBase/AWS_sync/cropped/anopheles/pretoriensis/',
#  'anopheles freeborni': '/opt/ImageBase/AWS_sync/cropped/anopheles/freeborni/',
#  'orthopodomyia signifera': '/opt/ImageBase/AWS_sync/cropped/orthopodomyia/signifera/',
#  'deinocerites cancer': '/opt/ImageBase/AWS_sync/cropped/deinocerites/cancer/',
#  'deinocerites cuba-1': '/opt/ImageBase/AWS_sync/cropped/deinocerites/cuba-1/',
#  'aedes canadensis': '/opt/ImageBase/AWS_sync/cropped/aedes/canadensis/',
#  'aedes triseriatus_sl': '/opt/ImageBase/AWS_sync/cropped/aedes/triseriatus_sl/',
#  'aedes triseriatus_sl sl': '/opt/ImageBase/AWS_sync/cropped/aedes/triseriatus_sl/sl/',
#  'aedes dorsalis': '/opt/ImageBase/AWS_sync/cropped/aedes/dorsalis/',
#  'aedes taeniorhynchus': '/opt/ImageBase/AWS_sync/cropped/aedes/taeniorhynchus/',
#  'aedes atlanticus': '/opt/ImageBase/AWS_sync/cropped/aedes/atlanticus/',
#  'aedes aegypti': '/opt/ImageBase/AWS_sync/cropped/aedes/aegypti/',
#  'aedes trivittatus': '/opt/ImageBase/AWS_sync/cropped/aedes/trivittatus/',
#  'aedes albopictus': '/opt/ImageBase/AWS_sync/cropped/aedes/albopictus/',
#  'aedes nigromaculis': '/opt/ImageBase/AWS_sync/cropped/aedes/nigromaculis/',
#  'aedes japonicus': '/opt/ImageBase/AWS_sync/cropped/aedes/japonicus/',
#  'aedes mediovittatus': '/opt/ImageBase/AWS_sync/cropped/aedes/mediovittatus/',
#  'aedes tortilis': '/opt/ImageBase/AWS_sync/cropped/aedes/tortilis/',
#  'aedes sollicitans': '/opt/ImageBase/AWS_sync/cropped/aedes/sollicitans/',
#  'aedes sierrensis': '/opt/ImageBase/AWS_sync/cropped/aedes/sierrensis/',
#  'aedes condolescens': '/opt/ImageBase/AWS_sync/cropped/aedes/condolescens/',
#  'aedes spp': '/opt/ImageBase/AWS_sync/cropped/aedes/spp/',
#  'aedes vexans': '/opt/ImageBase/AWS_sync/cropped/aedes/vexans/',
#  'aedes cinereus': '/opt/ImageBase/AWS_sync/cropped/aedes/cinereus/',
#  'aedes sticticus': '/opt/ImageBase/AWS_sync/cropped/aedes/sticticus/',
#  'aedes hendersoni': '/opt/ImageBase/AWS_sync/cropped/aedes/hendersoni/',
#  'aedes melanimon': '/opt/ImageBase/AWS_sync/cropped/aedes/melanimon/',
#  'aedes spilotus': '/opt/ImageBase/AWS_sync/cropped/aedes/spilotus/',
#  'aedes flavescens': '/opt/ImageBase/AWS_sync/cropped/aedes/flavescens/',
#  'aedes infirmatus': '/opt/ImageBase/AWS_sync/cropped/aedes/infirmatus/',
#  'aedes cantator': '/opt/ImageBase/AWS_sync/cropped/aedes/cantator/',
#  'aedes fairfax-1': '/opt/ImageBase/AWS_sync/cropped/aedes/fairfax-1/',
#  'mansonia titillans': '/opt/ImageBase/AWS_sync/cropped/mansonia/titillans/',
#  'coquillettidia perturbans': '/opt/ImageBase/AWS_sync/cropped/coquillettidia/perturbans/',
#  'culex erraticus': '/opt/ImageBase/AWS_sync/cropped/culex/erraticus/',
#  'culex bahamensis': '/opt/ImageBase/AWS_sync/cropped/culex/bahamensis/',
#  'culex pipiens_sl': '/opt/ImageBase/AWS_sync/cropped/culex/pipiens_sl/',
#  'culex nigripalpus': '/opt/ImageBase/AWS_sync/cropped/culex/nigripalpus/',
#  'culex territans': '/opt/ImageBase/AWS_sync/cropped/culex/territans/',
#  'culex salinarius': '/opt/ImageBase/AWS_sync/cropped/culex/salinarius/',
#  'culex spp': '/opt/ImageBase/AWS_sync/cropped/culex/spp/',
#  'culex tarsalis': '/opt/ImageBase/AWS_sync/cropped/culex/tarsalis/',
#  'culex antillummagnorum': '/opt/ImageBase/AWS_sync/cropped/culex/antillummagnorum/',
#  'culex coronator': '/opt/ImageBase/AWS_sync/cropped/culex/coronator/',
#  'culex restuans': '/opt/ImageBase/AWS_sync/cropped/culex/restuans/',
#  'uranotaenia sapphirina': '/opt/ImageBase/AWS_sync/cropped/uranotaenia/sapphirina/',
#  'culiseta melanura': '/opt/ImageBase/AWS_sync/cropped/culiseta/melanura/',
#  'culiseta incidens': '/opt/ImageBase/AWS_sync/cropped/culiseta/incidens/',
#  'culiseta inornata': '/opt/ImageBase/AWS_sync/cropped/culiseta/inornata/',
#  'non_mosquito': '/opt/ImageBase/AWS_sync/cropped/non_mosquito/'}

# %%
validate_split(split_df)
# Out:
# Index 0, Files found in /opt/ImageBase/AWS_sync/cropped/aedes/aegypti/: 921, Files according to split: 896
# Index 1, Files found in /opt/ImageBase/AWS_sync/cropped/aedes/albopictus/: 692, Files according to split: 725
# Index 3, Files found in /opt/ImageBase/AWS_sync/cropped/aedes/canadensis/: 128, Files according to split: 46
# Index 12, Files found in /opt/ImageBase/AWS_sync/cropped/aedes/japonicus/: 1093, Files according to split: 1103
# Index 13, Files found in /opt/ImageBase/AWS_sync/cropped/aedes/mediovittatus/: 84, Files according to split: 13
# Index 24, Files found in /opt/ImageBase/AWS_sync/cropped/aedes/vexans/: 364, Files according to split: 295
# Index 26, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/coustani/: 142, Files according to split: 148
# Index 28, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/b/: 74, Files according to split: 39
# Index 29, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/c/: 61, Files according to split: 14
# Index 30, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/crucians_sl/sl/: 114, Files according to split: 205
# Index 33, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/freeborni/: 570, Files according to split: 574
# Index 34, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/funestus_sl/sl/: 238, Files according to split: 28
# Index 36, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/arabiensis/: 800, Files according to split: 753
# Index 37, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/coluzzii/: 86, Files according to split: 96
# Index 38, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/sl/: 48, Files according to split: 222
# Index 39, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/gambiae_sl/ss/: 226, Files according to split: 110
# Index 45, Files found in /opt/ImageBase/AWS_sync/cropped/anopheles/punctipennis/: 212, Files according to split: 223
# Index 51, Files found in /opt/ImageBase/AWS_sync/cropped/coquillettidia/perturbans/: 204, Files according to split: 127
# Index 52, Files found in /opt/ImageBase/AWS_sync/cropped/culex/antillummagnorum/: 28, Files according to split: 13
# Index 55, Files found in /opt/ImageBase/AWS_sync/cropped/culex/erraticus/: 343, Files according to split: 346
# Index 57, Files found in /opt/ImageBase/AWS_sync/cropped/culex/pipiens_sl/: 1503, Files according to split: 1496
# Index 59, Files found in /opt/ImageBase/AWS_sync/cropped/culex/salinarius/: 163, Files according to split: 172
# Index 62, Files found in /opt/ImageBase/AWS_sync/cropped/culiseta/incidens/: 45, Files according to split: 53
# Index 69, Files found in /opt/ImageBase/AWS_sync/cropped/psorophora/ciliata/: 169, Files according to split: 173
# Index 70, Files found in /opt/ImageBase/AWS_sync/cropped/psorophora/columbiae/: 423, Files according to split: 403
# K.

# %%
"""
UNIQUE_CLASSES contains list of unique classes, in order
"""
UNIQUE_CLASSES = [i for i in split_df['unknown'].unique() if not pd.isnull(i)]
UNIQUE_CLASSES.extend([i for i in split_df['genus'].unique() if not pd.isnull(i)])
UNIQUE_CLASSES.extend([i for i in split_df['species'].unique() if not pd.isnull(i)])
UNIQUE_CLASSES.sort()
print(len(UNIQUE_CLASSES))
UNIQUE_CLASSES
# Out:
# 21
# ['aedes aedes_aegypti',
#  'aedes aedes_albopictus',
#  'aedes aedes_dorsalis',
#  'aedes aedes_sollicitans',
#  'aedes aedes_spp',
#  'aedes aedes_taeniorhynchus',
#  'aedes aedes_vexans',
#  'anopheles anopheles_coustani',
#  'anopheles anopheles_freeborni',
#  'anopheles anopheles_funestus',
#  'anopheles anopheles_gambiae',
#  'anopheles anopheles_punctipennis',
#  'anopheles anopheles_quadrimaculatus',
#  'anopheles anopheles_spp',
#  'culex culex_pipiens_sl',
#  'culex culex_salinarius',
#  'culex culex_spp',
#  'mosquito',
#  'psorophora psorophora_columbiae',
#  'psorophora psorophora_cyanescens',
#  'psorophora psorophora_spp']

# %%
# order with spp classes at the bottom
if FOLD==1:
    UNIQUE_CLASSES = ['aedes aedes_aegypti',
    'aedes aedes_albopictus',
    'aedes aedes_dorsalis',
    'aedes aedes_japonicus',
    'aedes aedes_sollicitans',
    'aedes aedes_vexans',
    'anopheles anopheles_coustani',
    'anopheles anopheles_crucians',
    'anopheles anopheles_freeborni',
    'anopheles anopheles_funestus',
    'anopheles anopheles_gambiae',
    'culex culex_erraticus',
    'culex culex_pipiens_sl',
    'culex culex_salinarius',
    'psorophora psorophora_columbiae',
    'psorophora psorophora_ferox',
    'aedes aedes_spp',               
    'anopheles anopheles_spp',
    'culex culex_spp',
    'psorophora psorophora_spp',
    'mosquito'] #fold1
elif FOLD ==2:

    UNIQUE_CLASSES = ['aedes aedes_albopictus',
    'aedes aedes_dorsalis',
    'aedes aedes_japonicus',
    'aedes aedes_taeniorhynchus',
    'aedes aedes_vexans',
    'anopheles anopheles_coustani',
    'anopheles anopheles_crucians',
    'anopheles anopheles_funestus',
    'anopheles anopheles_gambiae',
    'anopheles anopheles_punctipennis',
    'anopheles anopheles_quadrimaculatus',
    'culex culex_erraticus',
    'culex culex_salinarius',
    'psorophora psorophora_columbiae',
    'psorophora psorophora_cyanescens',
    'psorophora psorophora_ferox',
    'aedes aedes_spp',               
    'anopheles anopheles_spp',
    'culex culex_spp',
    'psorophora psorophora_spp',
    'mosquito'] #fold2
elif FOLD ==3:

    UNIQUE_CLASSES=['aedes aedes_aegypti',
    'aedes aedes_dorsalis',
    'aedes aedes_japonicus',
    'aedes aedes_sollicitans',
    'aedes aedes_taeniorhynchus',
    'anopheles anopheles_coustani',
    'anopheles anopheles_crucians',
    'anopheles anopheles_freeborni',
    'anopheles anopheles_gambiae',
    'anopheles anopheles_punctipennis',
    'anopheles anopheles_quadrimaculatus',
    'culex culex_erraticus',
    'culex culex_pipiens_sl',
    'psorophora psorophora_columbiae',
    'psorophora psorophora_cyanescens',
    'psorophora psorophora_ferox',
    'aedes aedes_spp',               
    'anopheles anopheles_spp',
    'culex culex_spp',
    'psorophora psorophora_spp',
    'mosquito'] #fold3
elif FOLD == 4:

    UNIQUE_CLASSES = ['aedes aedes_aegypti',
    'aedes aedes_albopictus',
    'aedes aedes_japonicus',
    'aedes aedes_sollicitans',
    'aedes aedes_taeniorhynchus',
    'aedes aedes_vexans',
    'anopheles anopheles_crucians',
    'anopheles anopheles_freeborni',
    'anopheles anopheles_funestus',
    'anopheles anopheles_punctipennis',
    'anopheles anopheles_quadrimaculatus',
    'culex culex_erraticus',
    'culex culex_pipiens_sl',
    'culex culex_salinarius',
    'psorophora psorophora_cyanescens',
    'psorophora psorophora_ferox',
    'aedes aedes_spp',               
    'anopheles anopheles_spp',
    'culex culex_spp',
    'psorophora psorophora_spp',
    'mosquito'] #fold4
elif FOLD==5:

    UNIQUE_CLASSES= ['aedes aedes_aegypti',
    'aedes aedes_albopictus',
    'aedes aedes_dorsalis',
    'aedes aedes_sollicitans',
    'aedes aedes_taeniorhynchus',
    'aedes aedes_vexans',
    'anopheles anopheles_coustani',
    'anopheles anopheles_freeborni',
    'anopheles anopheles_funestus',
    'anopheles anopheles_gambiae',
    'anopheles anopheles_punctipennis',
    'anopheles anopheles_quadrimaculatus',
    'culex culex_pipiens_sl',
    'culex culex_salinarius',
    'psorophora psorophora_columbiae',
    'psorophora psorophora_cyanescens',
    'aedes aedes_spp',               
    'anopheles anopheles_spp',
    'culex culex_spp',
    'psorophora psorophora_spp',
    'mosquito'] #fold5


UNIQUE_GENUSES = [
    'aedes',
    'anopheles',
    'culex',
    'psorophora',
    'mosquito'
]

# %%
"""
ROW_TO_CLASS maps each row in the split to a class
"""
ROW_TO_CLASS = {}
for i in tqdm(range(len(split_df))):
    setindx = False
    if not pd.isnull(split_df.loc[i, 'unknown']):
        ROW_TO_CLASS[i] = UNIQUE_CLASSES.index(split_df.loc[i, 'unknown'])
        setindx = True
    if not pd.isnull(split_df.loc[i, 'genus']):
        if setindx:
            raise ValueError('Resetting folder to class map')
        ROW_TO_CLASS[i] = UNIQUE_CLASSES.index(split_df.loc[i, 'genus'])
        setindx = True
    if not pd.isnull(split_df.loc[i, 'species']):
        if setindx:
            raise ValueError('Resetting folder to class map')
        ROW_TO_CLASS[i] = UNIQUE_CLASSES.index(split_df.loc[i, 'species'])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=79.0), HTML(value='')))

# %%
def split_helper(id_to_sample, ratio):
    """
    Split mosquito samples (not images, to prevent leakage)
    """
    df = pd.DataFrame(data=list(id_to_sample.keys()))
    trainlist, vallist, testlist = np.split(df.sample(frac=1), [int(ratio[0]*len(df)), int((ratio[0]+ratio[1])*len(df))])
    return trainlist, vallist, testlist

def join_lists(id_to_sample, mos_ids):
    """
    Takes mosquito sample IDs and returns list of images of those samples
    Eg: [000429] -> ['JHU-000429_05m.jpg', 'JHU-000429_04m.jpg', 'JHU-000429_02m.jpg']
    """
    jointlist = []
    for mos in mos_ids:
        jointlist.extend(id_to_sample[mos])
    return jointlist

def split_imlist(imlist, ratio):
    """
    Takes a list of images, and splits them into training, validation and test sets in the provided ratio.
    The ratio will not be followed strictly. The samples are split according to the ratio, and since
    the samples may have different number of images, the ratio of actual number of images might vary.
    
    Just repeat the split process multiple times if you don't like the number of images in splits.
    """
    id_to_sample = {}
    for im in imlist:
        mosid = im.split('/')[-1].split('_')[0].split('-')[-1]
        if mosid in id_to_sample:
            id_to_sample[mosid].append(im)
        else:
            id_to_sample[mosid] = [im]
    
    trainlist, vallist, testlist = split_helper(id_to_sample, ratio)
    try:
#         print(type(trainlist[0]), len(trainlist[0]))
        trainlist = join_lists(id_to_sample, trainlist[0])
    except:
        sys.exit(trainlist[0])
    vallist = join_lists(id_to_sample, vallist[0])
    testlist = join_lists(id_to_sample, testlist[0])
    return trainlist, vallist, testlist

# %%
def extend_df(output_df, imlist, targetgenus, targetclass, split, genus_name, species_name):
    """
    Add samples to the dataframe with their class and split
    """
    temp_df = pd.DataFrame(data=imlist, columns=['Id'])
    temp_df['Genus'] = targetgenus
    temp_df['Species'] = targetclass
    temp_df['Split'] = split
    temp_df['Genus_Name'] = genus_name
    temp_df['Species_Name'] = species_name
    temp_df = temp_df[output_df.columns]
    return output_df.append(temp_df).reset_index(drop=True)
    
def prepare_data(split_df, ratio=[0.7, 0.15, 0.15], fold='fold'):
    """
    Takes in split_df, ratio and fold column name, and outputs splits
    """
    output_df = pd.DataFrame(columns=['Id','Genus','Species','Split','Genus_Name','Species_Name'])
    for i in tqdm(range(len(split_df))):
        sourcepath = SPECIES_TO_PATH[split_df.loc[i, 'folder']]
        imlist = glob.glob(sourcepath + '*m.jpg')
        targetclass = ROW_TO_CLASS[i]
        targetgenus = UNIQUE_GENUSES.index(UNIQUE_CLASSES[targetclass].split(' ')[0])
        genus_name = UNIQUE_GENUSES[targetgenus]
        species_name = 'mosquito' if genus_name == 'mosquito' else UNIQUE_CLASSES[targetclass].split(' ')[1]
        
        if split_df.loc[i, fold] == 'tr/v/t':
            trainlist, vallist, testlist = split_imlist(imlist, ratio)
            output_df = extend_df(output_df, trainlist, targetgenus, targetclass, 'Train', genus_name, species_name)
            output_df = extend_df(output_df, vallist, targetgenus, targetclass, 'Valid', genus_name, species_name)
            output_df = extend_df(output_df, testlist, targetgenus, targetclass, 'Test', genus_name, species_name)
        
        else:
            output_df = extend_df(output_df, imlist, targetgenus, targetclass, 'ExtendedTest', genus_name, species_name)

    return output_df

# %%
output_df = prepare_data(split_df, ratio=[0.71, 0.15, 0.15])
print("Total number of images: ", len(output_df))
traincount = (output_df['Split'] == 'Train').sum()
valcount = (output_df['Split'] == 'Valid').sum()
testcount = (output_df['Split'] == 'Test').sum()
extendedtestcount = (output_df['Split'] == 'ExtendedTest').sum()

print("Train images: {}, Valid iamges: {}, Test images: {}, Extended Test images: {}".format(traincount, 
        valcount, testcount, extendedtestcount))
totalcount = traincount + valcount + testcount
print("Train/Valid/Test Ratio: {:.4f}, {:.4f}, {:.4f}".format(traincount/totalcount, 
                                                              valcount/totalcount, testcount/totalcount))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=79.0), HTML(value='')))
# Total number of images:  12977
# Train images: 7322, Valid iamges: 1575, Test images: 1558, Extended Test images: 2522
# Train/Valid/Test Ratio: 0.7003, 0.1506, 0.1490

# %%
pd.set_option('display.max_colwidth', -1)
output_df
# Out:
# /home/vectorweb3/anaconda3/envs/novelty_detection/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
#                                                                               Id  \
# 0      /opt/ImageBase/AWS_sync/cropped/aedes/aegypti/JHU-005975_02m.jpg
# 1      /opt/ImageBase/AWS_sync/cropped/aedes/aegypti/JHU-005975_01m.jpg
# 2      /opt/ImageBase/AWS_sync/cropped/aedes/aegypti/JHU-005975_04m.jpg
# 3      /opt/ImageBase/AWS_sync/cropped/aedes/aegypti/JHU-005975_06m.jpg
# 4      /opt/ImageBase/AWS_sync/cropped/aedes/aegypti/JHU-005975_09m.jpg
# ...                                                                 ...
# 12972  /opt/ImageBase/AWS_sync/cropped/uranotaenia/sapphirina/JHU-000430_05m.jpg
# 12973  /opt/ImageBase/AWS_sync/cropped/uranotaenia/sapphirina/JHU-000429_05m.jpg
# 12974  /opt/ImageBase/AWS_sync/cropped/uranotaenia/sapphirina/JHU-000429_03m.jpg
# 12975  /opt/ImageBase/AWS_sync/cropped/uranotaenia/sapphirina/JHU-000429_01m.jpg
# 12976  /opt/ImageBase/AWS_sync/cropped/uranotaenia/sapphirina/JHU-000430_04m.jpg
#
#       Genus Species         Split Genus_Name   Species_Name
# 0      0     0       Train         aedes      aedes_aegypti
# 1      0     0       Train         aedes      aedes_aegypti
# 2      0     0       Train         aedes      aedes_aegypti
# 3      0     0       Train         aedes      aedes_aegypti
# 4      0     0       Train         aedes      aedes_aegypti
# ...   ..    ..         ...           ...                ...
# 12972  4     17      ExtendedTest  mosquito   mosquito
# 12973  4     17      ExtendedTest  mosquito   mosquito
# 12974  4     17      ExtendedTest  mosquito   mosquito
# 12975  4     17      ExtendedTest  mosquito   mosquito
# 12976  4     17      ExtendedTest  mosquito   mosquito
#
# [12977 rows x 6 columns]

# %% [markdown]
# ## Validating Data

# %% [markdown]
# ### Regenerate the class and genus mapping from Image paths

# %%
re_class_map = {i: [] for i in range(output_df['Species'].nunique())}
re_genus_map = {i: [] for i in range(output_df['Genus'].nunique())}
for i, row in output_df.iterrows():
    cls_name = ' '.join(row['Id'].split('/')[-3:-1])
    if cls_name not in re_class_map[row['Species']]:
        re_class_map[row['Species']].append(cls_name)

# %%
comp_df = []
for i in range(len(UNIQUE_CLASSES)):
    comp_df.append({'Class': i, 'Original': UNIQUE_CLASSES[i], 'Inferred': re_class_map[i]})
comp_df = pd.DataFrame(comp_df)
comp_df
# Out:
#     Class                             Original  \
# 0   0      aedes aedes_aegypti
# 1   1      aedes aedes_albopictus
# 2   2      aedes aedes_dorsalis
# 3   3      aedes aedes_sollicitans
# 4   4      aedes aedes_spp
# 5   5      aedes aedes_taeniorhynchus
# 6   6      aedes aedes_vexans
# 7   7      anopheles anopheles_coustani
# 8   8      anopheles anopheles_freeborni
# 9   9      anopheles anopheles_funestus
# 10  10     anopheles anopheles_gambiae
# 11  11     anopheles anopheles_punctipennis
# 12  12     anopheles anopheles_quadrimaculatus
# 13  13     anopheles anopheles_spp
# 14  14     culex culex_pipiens_sl
# 15  15     culex culex_salinarius
# 16  16     culex culex_spp
# 17  17     mosquito
# 18  18     psorophora psorophora_columbiae
# 19  19     psorophora psorophora_cyanescens
# 20  20     psorophora psorophora_spp
#
#                                                                                                                                                                                                                                                                                                                                Inferred
# 0   [aedes aegypti]
# 1   [aedes albopictus]
# 2   [aedes dorsalis]
# 3   [aedes sollicitans]
# 4   [aedes atlanticus, aedes canadensis, aedes cantator, aedes condolescens, aedes fairfax-1, aedes flavescens, aedes hendersoni, aedes infirmatus, aedes japonicus, aedes mediovittatus, aedes melanimon, aedes nigromaculis, aedes sierrensis, aedes spilotus, aedes sticticus, aedes tortilis, triseriatus_sl sl, aedes trivittatus]
# 5   [aedes taeniorhynchus]
# 6   [aedes vexans]
# 7   [anopheles coustani]
# 8   [anopheles freeborni]
# 9   [funestus_sl sl, funestus_sl ss]
# 10  [gambiae_sl arabiensis, gambiae_sl coluzzii, gambiae_sl sl, gambiae_sl ss]
# 11  [anopheles punctipennis]
# 12  [anopheles quadrimaculatus]
# 13  [anopheles cf-coustani, crucians_sl a, crucians_sl b, crucians_sl c, crucians_sl sl, crucians_sl d, crucians_sl e, anopheles maculipalpis, anopheles pharoensis, anopheles pretoriensis, anopheles pseudopunctipennis, anopheles rufipes, anopheles squamosus, anopheles tenebrosus, anopheles ziemanni]
# 14  [culex pipiens_sl]
# 15  [culex salinarius]
# 16  [culex antillummagnorum, culex bahamensis, culex coronator, culex erraticus, culex nigripalpus, culex restuans, culex tarsalis, culex territans]
# 17  [coquillettidia perturbans, culiseta incidens, culiseta inornata, culiseta melanura, deinocerites cancer, deinocerites cuba-1, mansonia titillans, orthopodomyia signifera, uranotaenia sapphirina]
# 18  [psorophora columbiae]
# 19  [psorophora cyanescens]
# 20  [psorophora ciliata, psorophora discolor, psorophora ferox, psorophora howardii, psorophora pygmaea, psorophora signipennis]

# %% [markdown]
# ### Validate that no two images of the same sample are split in different sets

# %%
sample_to_set = {}
for i, row in output_df.iterrows():
    sample = row['Id'].split('/')[-1].split('_')[0]
    if sample in sample_to_set:
        assert row['Split'] == sample_to_set[sample]
    else:
        sample_to_set[sample] = row['Split']
print("Congratulations. No specimen leak.")
print('Total number of specimens: ', len(sample_to_set))
# Out:
# Congratulations. No specimen leak.
# Total number of specimens:  2696

# %% [markdown]
# ## Save DF

# %%
output_df.to_csv('datasplit_fold{}.csv'.format(FOLD), index=False)
print('FOLD: ',FOLD)
# Out:
# FOLD:  5

# %% [markdown]
# ## Load DF and report images in each species

# %%
split_df = pd.read_csv(f'./datasplit_fold1.csv')
unique_sp = {}
for i in range(len(split_df)):
    tmp_id = split_df['Id'][i].split('/')
    tmp_sp = tmp_id[-3].capitalize()+' '+tmp_id[-2]
    if tmp_sp not in unique_sp:
        unique_sp[tmp_sp]=1
    else:
        unique_sp[tmp_sp]+=1
for sp in unique_sp:
    print(sp,unique_sp[sp])
# Out:
# Aedes aegypti 921
# Aedes albopictus 692
# Aedes atlanticus 80
# Aedes canadensis 128
# Aedes cantator 8
# Aedes condolescens 10
# Aedes dorsalis 288
# Aedes fairfax-1 6
# Aedes flavescens 72
# Aedes hendersoni 16
# Aedes infirmatus 106
# Aedes japonicus 1093
# Aedes mediovittatus 84
# Aedes melanimon 20
# Aedes nigromaculis 42
# Aedes sierrensis 8
# Aedes sollicitans 414
# Aedes spilotus 4
# Aedes sticticus 4
# Aedes taeniorhynchus 184
# Aedes tortilis 21
# Triseriatus_sl sl 87
# Aedes trivittatus 143
# Aedes vexans 364
# Anopheles cf-coustani 21
# Anopheles coustani 142
# Crucians_sl a 19
# Crucians_sl b 74
# Crucians_sl c 61
# Crucians_sl sl 114
# Crucians_sl d 5
# Crucians_sl e 5
# Anopheles freeborni 570
# Funestus_sl sl 238
# Funestus_sl ss 972
# Gambiae_sl arabiensis 800
# Gambiae_sl coluzzii 86
# Gambiae_sl sl 48
# Gambiae_sl ss 226
# Anopheles maculipalpis 30
# Anopheles pharoensis 6
# Anopheles pretoriensis 12
# Anopheles pseudopunctipennis 53
# Anopheles punctipennis 212
# Anopheles quadrimaculatus 195
# Anopheles rufipes 12
# Anopheles squamosus 13
# Anopheles tenebrosus 6
# Anopheles ziemanni 35
# Coquillettidia perturbans 204
# Culex antillummagnorum 28
# Culex bahamensis 4
# Culex coronator 61
# Culex erraticus 343
# Culex nigripalpus 74
# Culex pipiens_sl 1503
# Culex restuans 80
# Culex salinarius 163
# Culex tarsalis 14
# Culex territans 13
# Culiseta incidens 45
# Culiseta inornata 46
# Culiseta melanura 5
# Deinocerites cancer 39
# Deinocerites cuba-1 72
# Mansonia titillans 93
# Orthopodomyia signifera 18
# Psorophora ciliata 169
# Psorophora columbiae 423
# Psorophora cyanescens 390
# Psorophora discolor 10
# Psorophora ferox 231
# Psorophora howardii 17
# Psorophora pygmaea 149
# Psorophora signipennis 23
# Uranotaenia sapphirina 10
